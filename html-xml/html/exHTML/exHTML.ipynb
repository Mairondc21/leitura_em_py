# %%
import pandas as pd
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQuBG-JoWaeQF5rF3RgZYl5Z-PaJyDBK1I1c8a56RssNGoOlInqQROKi3z54u74E2ei32p_SWOpBb0v/pubhtml'

# %%
df = pd.read_html(url,encoding='ISO-8859-1')

# %%
dados_gatito = df[0]

# %%
dados_gatito.to_csv('produtos_gatito.csv',index=False,encoding='ISO-8859-1')

# %%
index_gatito = ['ID Produto','Nome produto','Categoria','Marca','Valor','Url img']
df = pd.read_csv('produtos_gatito.csv',skiprows=1,usecols=lambda column: column != '1',index_col=False)
df
# Out:
#     ID Produto       Nome produto  Categoria       Marca     Valor  \
# 0            1  Ração filhote 1kg   Alimento      Gatito  R$ 21,00
# 1            2   Ração adulto 1kg   Alimento      Gatito  R$ 24,00
# 2            3   Ração sênior 1kg   Alimento      Gatito  R$ 27,00
# 3            4            Petisco   Alimento      Gatito   R$ 6,00
# 4            5            Ratinho  Brinquedo      Gatito   R$ 7,00
# 5            6            Varinha  Brinquedo      Gatito  R$ 20,00
# 6            7   Roupa de inverno      Roupa      Gatito  R$ 60,00
# 7            8     Roupa de verão      Roupa      Gatito  R$ 45,00
# 8            9            Coleira  Acessório      Gatito  R$ 30,00
# 9           10               Guia  Acessório      Gatito  R$ 70,00
# 10          11  Ração filhote 1kg   Alimento  Cachorrito  R$ 42,00
# 11          12   Ração adulto 1kg   Alimento  Cachorrito  R$ 46,00
# 12          13   Ração sênior 1kg   Alimento  Cachorrito  R$ 50,00
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.columns
# Out:
# Index(['ID Produto', 'Nome produto', 'Categoria', 'Marca', 'Valor', 'Url img'], dtype='object')

# %%
df.isnull()
# Out:
#     ID Produto  Nome produto  Categoria  Marca  Valor  Url img
# 0        False         False      False  False  False    False
# 1        False         False      False  False  False    False
# 2        False         False      False  False  False    False
# 3        False         False      False  False  False    False
# 4        False         False      False  False  False    False
# 5        False         False      False  False  False    False
# 6        False         False      False  False  False    False
# 7        False         False      False  False  False    False
# 8        False         False      False  False  False    False
# 9        False         False      False  False  False    False
# 10       False         False      False  False  False    False
# 11       False         False      False  False  False    False
# 12       False         False      False  False  False    False
# 13       False         False      False  False  False    False
# ...

# %%
df.head()
# Out:
#    ID Produto       Nome produto  Categoria   Marca     Valor  \
# 0           1  Ração filhote 1kg   Alimento  Gatito  R$ 21,00
# 1           2   Ração adulto 1kg   Alimento  Gatito  R$ 24,00
# 2           3   Ração sênior 1kg   Alimento  Gatito  R$ 27,00
# 3           4            Petisco   Alimento  Gatito   R$ 6,00
# 4           5            Ratinho  Brinquedo  Gatito   R$ 7,00
#
#                                              Url img
# 0  https://caelum-online-public.s3.amazonaws.com/...
# 1  https://caelum-online-public.s3.amazonaws.com/...
# 2  https://caelum-online-public.s3.amazonaws.com/...
# 3  https://caelum-online-public.s3.amazonaws.com/...
# 4  https://caelum-online-public.s3.amazonaws.com/...

# %%
df.to_csv('gatitos.csv',index=False)

# %%
pd.read_csv('gatitos.csv')
# Out:
#     ID Produto       Nome produto  Categoria       Marca     Valor  \
# 0            1  Ração filhote 1kg   Alimento      Gatito  R$ 21,00
# 1            2   Ração adulto 1kg   Alimento      Gatito  R$ 24,00
# 2            3   Ração sênior 1kg   Alimento      Gatito  R$ 27,00
# 3            4            Petisco   Alimento      Gatito   R$ 6,00
# 4            5            Ratinho  Brinquedo      Gatito   R$ 7,00
# 5            6            Varinha  Brinquedo      Gatito  R$ 20,00
# 6            7   Roupa de inverno      Roupa      Gatito  R$ 60,00
# 7            8     Roupa de verão      Roupa      Gatito  R$ 45,00
# 8            9            Coleira  Acessório      Gatito  R$ 30,00
# 9           10               Guia  Acessório      Gatito  R$ 70,00
# 10          11  Ração filhote 1kg   Alimento  Cachorrito  R$ 42,00
# 11          12   Ração adulto 1kg   Alimento  Cachorrito  R$ 46,00
# 12          13   Ração sênior 1kg   Alimento  Cachorrito  R$ 50,00
# ...
